# %%
from collections import deque
from typing import List, Set, Tuple

def read_input_file(filename: str) -> str:
    """Read the input from a text file."""
    with open(filename, 'r') as file:
        return file.read().strip()

def find_trailheads(grid: List[List[int]]) -> List[Tuple[int, int]]:
    """Find all positions with height 0 in the grid."""
    trailheads = []
    rows, cols = len(grid), len(grid[0])
    for i in range(rows):
        for j in range(cols):
            if grid[i][j] == 0:
                trailheads.append((i, j))
    return trailheads

def get_valid_neighbors(pos: Tuple[int, int], rows: int, cols: int) -> List[Tuple[int, int]]:
    """Get all valid neighboring positions (up, down, left, right)."""
    i, j = pos
    neighbors = []
    for di, dj in [(0, 1), (1, 0), (0, -1), (-1, 0)]:  # right, down, left, up
        ni, nj = i + di, j + dj
        if 0 <= ni < rows and 0 <= nj < cols:
            neighbors.append((ni, nj))
    return neighbors

def calculate_trailhead_score(grid: List[List[int]], start: Tuple[int, int]) -> int:
    """
    Calculate the score for a trailhead by finding all reachable height-9 positions
    via valid hiking trails (increasing by exactly 1 at each step).
    """
    rows, cols = len(grid), len(grid[0])
    reachable_nines = set()
    visited = set()
    
    def dfs(pos: Tuple[int, int], current_height: int, path: Set[Tuple[int, int]]):
        if current_height == 9:
            reachable_nines.add(pos)
            return
        
        i, j = pos
        for ni, nj in get_valid_neighbors(pos, rows, cols):
            next_pos = (ni, nj)
            if (next_pos not in path and 
                grid[ni][nj] == current_height + 1):
                new_path = path | {next_pos}
                dfs(next_pos, current_height + 1, new_path)
    
    # Start DFS from the trailhead
    dfs(start, 0, {start})
    return len(reachable_nines)

def solve_hiking_trails(grid_str: str) -> int:
    """
    Main solving function that processes the input and calculates
    the sum of all trailhead scores.
    """
    # Convert input string to grid
    grid = [[int(c) for c in line.strip()] 
            for line in grid_str.strip().split('\n')]
    
    # Find all trailheads
    trailheads = find_trailheads(grid)
    
    # Calculate score for each trailhead
    total_score = 0
    for trailhead in trailheads:
        score = calculate_trailhead_score(grid, trailhead)
        total_score += score
        
    return total_score

def main():
    # Replace 'input.txt' with your actual input file name
    try:
        input_data = read_input_file('puzzle_input.txt')
        result = solve_hiking_trails(input_data)
        print(f"Sum of trailhead scores: {result}")
    except FileNotFoundError:
        print("Error: input.txt file not found!")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# Sum of trailhead scores: 517

# %%
from collections import deque
from typing import List, Set, Tuple

def read_input_file(filename: str) -> str:
    """Read the input from a text file."""
    with open(filename, 'r') as file:
        return file.read().strip()

def find_trailheads(grid: List[List[int]]) -> List[Tuple[int, int]]:
    """Find all positions with height 0 in the grid."""
    trailheads = []
    rows, cols = len(grid), len(grid[0])
    for i in range(rows):
        for j in range(cols):
            if grid[i][j] == 0:
                trailheads.append((i, j))
    return trailheads

def get_valid_neighbors(pos: Tuple[int, int], rows: int, cols: int) -> List[Tuple[int, int]]:
    """Get all valid neighboring positions (up, down, left, right)."""
    i, j = pos
    neighbors = []
    for di, dj in [(0, 1), (1, 0), (0, -1), (-1, 0)]:  # right, down, left, up
        ni, nj = i + di, j + dj
        if 0 <= ni < rows and 0 <= nj < cols:
            neighbors.append((ni, nj))
    return neighbors

def calculate_trailhead_rating(grid: List[List[int]], start: Tuple[int, int]) -> int:
    """
    Calculate the rating for a trailhead by counting the number of distinct
    hiking trails that reach height 9.
    """
    rows, cols = len(grid), len(grid[0])
    distinct_paths = 0
    
    def dfs(pos: Tuple[int, int], current_height: int, path: Set[Tuple[int, int]]):
        nonlocal distinct_paths
        i, j = pos
        
        # If we reached height 9, we found a valid path
        if grid[i][j] == 9:
            distinct_paths += 1
            return
        
        # Try all valid neighbors
        for ni, nj in get_valid_neighbors(pos, rows, cols):
            next_pos = (ni, nj)
            if (next_pos not in path and 
                grid[ni][nj] == current_height + 1):
                new_path = path | {next_pos}
                dfs(next_pos, current_height + 1, new_path)
    
    # Start DFS from the trailhead
    dfs(start, 0, {start})
    return distinct_paths

def solve_hiking_trails(grid_str: str) -> int:
    """
    Main solving function that processes the input and calculates
    the sum of all trailhead ratings.
    """
    # Convert input string to grid
    grid = [[int(c) for c in line.strip()] 
            for line in grid_str.strip().split('\n')]
    
    # Find all trailheads
    trailheads = find_trailheads(grid)
    
    # Calculate rating for each trailhead
    total_rating = 0
    for i, trailhead in enumerate(trailheads):
        rating = calculate_trailhead_rating(grid, trailhead)
        total_rating += rating
        print(f"Trailhead {i+1} at position {trailhead}: rating = {rating}")
        
    return total_rating

def main():
    # Test with the example from the problem
    example = """
89010123
78121874
87430965
96549874
45678903
32019012
01329801
10456732
""".strip()
    
    print("Testing with example input:")
    result = solve_hiking_trails(example)
    print(f"\nSum of trailhead ratings: {result}")  # Should output 81
    
    # Process actual input file if it exists
    try:
        print("\nProcessing input file:")
        input_data = read_input_file('puzzle_input.txt')
        result = solve_hiking_trails(input_data)
        print(f"\nSum of trailhead ratings: {result}")
    except FileNotFoundError:
        print("\nNote: input.txt file not found. Skipping file input.")
    except Exception as e:
        print(f"\nAn error occurred while processing file: {e}")

if __name__ == "__main__":
    main()
# Out:
# Testing with example input:
# Trailhead 1 at position (0, 2): rating = 20
# Trailhead 2 at position (0, 4): rating = 24
# Trailhead 3 at position (2, 4): rating = 10
# Trailhead 4 at position (4, 6): rating = 4
# Trailhead 5 at position (5, 2): rating = 1
# Trailhead 6 at position (5, 5): rating = 4
# Trailhead 7 at position (6, 0): rating = 5
# Trailhead 8 at position (6, 6): rating = 8
# Trailhead 9 at position (7, 1): rating = 5
#
# Sum of trailhead ratings: 81
#
# Processing input file:
# Trailhead 1 at position (0, 6): rating = 1
# Trailhead 2 at position (0, 10): rating = 1
# Trailhead 3 at position (0, 18): rating = 16
# Trailhead 4 at position (0, 24): rating = 4
# Trailhead 5 at position (0, 30): rating = 2
# Trailhead 6 at position (1, 0): rating = 3
# Trailhead 7 at position (1, 1): rating = 2
# Trailhead 8 at position (1, 19): rating = 8
# Trailhead 9 at position (1, 26): rating = 3
# Trailhead 10 at position (1, 31): rating = 19
# Trailhead 11 at position (2, 40): rating = 12
# Trailhead 12 at position (3, 2): rating = 3
# Trailhead 13 at position (3, 9): rating = 1
# Trailhead 14 at position (3, 11): rating = 1
# Trailhead 15 at position (3, 12): rating = 4
# Trailhead 16 at position (3, 16): rating = 7
# Trailhead 17 at position (3, 27): rating = 2
# Trailhead 18 at position (3, 35): rating = 22
# Trailhead 19 at position (4, 10): rating = 1
# Trailhead 20 at position (4, 17): rating = 7
# Trailhead 21 at position (4, 23): rating = 11
# Trailhead 22 at position (4, 40): rating = 24
# Trailhead 23 at position (4, 44): rating = 3
# Trailhead 24 at position (5, 41): rating = 2
# Trailhead 25 at position (6, 10): rating = 2
# Trailhead 26 at position (6, 13): rating = 11
# Trailhead 27 at position (6, 15): rating = 6
# Trailhead 28 at position (6, 34): rating = 4
# Trailhead 29 at position (7, 3): rating = 5
# Trailhead 30 at position (7, 4): rating = 1
# Trailhead 31 at position (7, 22): rating = 4
# Trailhead 32 at position (7, 23): rating = 2
# Trailhead 33 at position (7, 25): rating = 2
# Trailhead 34 at position (7, 36): rating = 3
# Trailhead 35 at position (7, 43): rating = 2
# Trailhead 36 at position (8, 1): rating = 2
# Trailhead 37 at position (8, 12): rating = 9
# Trailhead 38 at position (8, 27): rating = 2
# Trailhead 39 at position (8, 29): rating = 3
# Trailhead 40 at position (8, 32): rating = 4
# Trailhead 41 at position (8, 41): rating = 1
# Trailhead 42 at position (9, 9): rating = 8
# Trailhead 43 at position (9, 29): rating = 1
# Trailhead 44 at position (9, 33): rating = 8
# Trailhead 45 at position (9, 38): rating = 6
# Trailhead 46 at position (10, 10): rating = 5
# Trailhead 47 at position (10, 16): rating = 5
# Trailhead 48 at position (10, 27): rating = 1
# Trailhead 49 at position (10, 43): rating = 2
# Trailhead 50 at position (11, 0): rating = 4
# Trailhead 51 at position (11, 24): rating = 2
# Trailhead 52 at position (11, 33): rating = 16
# Trailhead 53 at position (11, 39): rating = 1
# Trailhead 54 at position (12, 0): rating = 8
# Trailhead 55 at position (12, 16): rating = 1
# Trailhead 56 at position (12, 19): rating = 3
# Trailhead 57 at position (12, 20): rating = 2
# Trailhead 58 at position (12, 34): rating = 8
# Trailhead 59 at position (13, 3): rating = 8
# Trailhead 60 at position (13, 5): rating = 4
# Trailhead 61 at position (13, 9): rating = 11
# Trailhead 62 at position (13, 18): rating = 2
# Trailhead 63 at position (13, 20): rating = 10
# Trailhead 64 at position (13, 24): rating = 4
# Trailhead 65 at position (13, 32): rating = 3
# Trailhead 66 at position (13, 36): rating = 1
# Trailhead 67 at position (13, 37): rating = 2
# Trailhead 68 at position (13, 41): rating = 2
# Trailhead 69 at position (14, 0): rating = 16
# Trailhead 70 at position (14, 25): rating = 2
# Trailhead 71 at position (15, 1): rating = 9
# Trailhead 72 at position (15, 10): rating = 8
# Trailhead 73 at position (15, 13): rating = 6
# Trailhead 74 at position (15, 15): rating = 2
# Trailhead 75 at position (15, 28): rating = 10
# Trailhead 76 at position (16, 0): rating = 1
# Trailhead 77 at position (16, 2): rating = 1
# Trailhead 78 at position (16, 5): rating = 1
# Trailhead 79 at position (16, 20): rating = 10
# Trailhead 80 at position (16, 23): rating = 2
# Trailhead 81 at position (16, 40): rating = 3
# Trailhead 82 at position (17, 4): rating = 3
# Trailhead 83 at position (17, 19): rating = 15
# Trailhead 84 at position (17, 37): rating = 11
# Trailhead 85 at position (18, 31): rating = 2
# Trailhead 86 at position (18, 32): rating = 1
# Trailhead 87 at position (19, 5): rating = 2
# Trailhead 88 at position (19, 9): rating = 5
# Trailhead 89 at position (19, 11): rating = 5
# Trailhead 90 at position (19, 13): rating = 4
# Trailhead 91 at position (19, 18): rating = 1
# Trailhead 92 at position (19, 19): rating = 5
# Trailhead 93 at position (19, 26): rating = 1
# Trailhead 94 at position (20, 7): rating = 8
# Trailhead 95 at position (20, 12): rating = 2
# Trailhead 96 at position (20, 28): rating = 1
# Trailhead 97 at position (20, 37): rating = 2
# Trailhead 98 at position (20, 39): rating = 1
# Trailhead 99 at position (20, 42): rating = 2
# Trailhead 100 at position (20, 43): rating = 1
# Trailhead 101 at position (21, 6): rating = 8
# Trailhead 102 at position (21, 10): rating = 1
# Trailhead 103 at position (21, 43): rating = 9
# Trailhead 104 at position (22, 10): rating = 4
# Trailhead 105 at position (22, 19): rating = 3
# Trailhead 106 at position (22, 26): rating = 12
# Trailhead 107 at position (22, 36): rating = 2
# Trailhead 108 at position (23, 1): rating = 2
# Trailhead 109 at position (23, 5): rating = 9
# Trailhead 110 at position (23, 25): rating = 22
# Trailhead 111 at position (23, 27): rating = 7
# Trailhead 112 at position (23, 31): rating = 5
# Trailhead 113 at position (24, 0): rating = 2
# Trailhead 114 at position (24, 6): rating = 7
# Trailhead 115 at position (24, 10): rating = 1
# Trailhead 116 at position (24, 14): rating = 8
# Trailhead 117 at position (24, 24): rating = 10
# Trailhead 118 at position (24, 30): rating = 5
# Trailhead 119 at position (24, 42): rating = 12
# Trailhead 120 at position (24, 44): rating = 24
# Trailhead 121 at position (25, 20): rating = 3
# Trailhead 122 at position (25, 32): rating = 6
# Trailhead 123 at position (26, 4): rating = 4
# Trailhead 124 at position (26, 10): rating = 10
# Trailhead 125 at position (26, 16): rating = 4
# Trailhead 126 at position (26, 21): rating = 6
# Trailhead 127 at position (26, 36): rating = 7
# Trailhead 128 at position (26, 41): rating = 1
# Trailhead 129 at position (27, 9): rating = 8
# Trailhead 130 at position (27, 17): rating = 8
# Trailhead 131 at position (27, 22): rating = 3
# Trailhead 132 at position (27, 27): rating = 6
# Trailhead 133 at position (27, 35): rating = 7
# Trailhead 134 at position (28, 4): rating = 4
# Trailhead 135 at position (28, 15): rating = 10
# Trailhead 136 at position (28, 27): rating = 10
# Trailhead 137 at position (28, 40): rating = 1
# Trailhead 138 at position (29, 11): rating = 16
# Trailhead 139 at position (29, 16): rating = 20
# Trailhead 140 at position (29, 18): rating = 10
# Trailhead 141 at position (29, 25): rating = 8
# Trailhead 142 at position (29, 38): rating = 6
# Trailhead 143 at position (30, 0): rating = 5
# Trailhead 144 at position (30, 8): rating = 7
# Trailhead 145 at position (31, 1): rating = 2
# Trailhead 146 at position (31, 5): rating = 5
# Trailhead 147 at position (31, 33): rating = 2
# Trailhead 148 at position (31, 38): rating = 6
# Trailhead 149 at position (32, 7): rating = 2
# Trailhead 150 at position (32, 13): rating = 5
# Trailhead 151 at position (32, 22): rating = 2
# Trailhead 152 at position (32, 23): rating = 6
# Trailhead 153 at position (32, 25): rating = 3
# Trailhead 154 at position (32, 27): rating = 3
# Trailhead 155 at position (32, 44): rating = 1
# Trailhead 156 at position (33, 16): rating = 12
# Trailhead 157 at position (33, 25): rating = 2
# Trailhead 158 at position (33, 42): rating = 2
# Trailhead 159 at position (33, 44): rating = 2
# Trailhead 160 at position (34, 2): rating = 6
# Trailhead 161 at position (34, 17): rating = 7
# Trailhead 162 at position (34, 22): rating = 2
# Trailhead 163 at position (34, 35): rating = 4
# Trailhead 164 at position (35, 6): rating = 3
# Trailhead 165 at position (35, 10): rating = 2
# Trailhead 166 at position (35, 13): rating = 2
# Trailhead 167 at position (35, 28): rating = 4
# Trailhead 168 at position (35, 36): rating = 4
# Trailhead 169 at position (35, 43): rating = 3
# Trailhead 170 at position (36, 13): rating = 1
# Trailhead 171 at position (36, 32): rating = 3
# Trailhead 172 at position (36, 36): rating = 3
# Trailhead 173 at position (36, 40): rating = 5
# Trailhead 174 at position (36, 42): rating = 7
# Trailhead 175 at position (37, 7): rating = 5
# Trailhead 176 at position (37, 14): rating = 2
# Trailhead 177 at position (37, 16): rating = 1
# Trailhead 178 at position (37, 19): rating = 4
# Trailhead 179 at position (37, 24): rating = 1
# Trailhead 180 at position (37, 30): rating = 4
# Trailhead 181 at position (38, 2): rating = 2
# Trailhead 182 at position (38, 6): rating = 3
# Trailhead 183 at position (38, 10): rating = 5
# Trailhead 184 at position (38, 18): rating = 7
# Trailhead 185 at position (38, 34): rating = 3
# Trailhead 186 at position (38, 36): rating = 6
# Trailhead 187 at position (38, 40): rating = 1
# Trailhead 188 at position (38, 41): rating = 1
# Trailhead 189 at position (39, 36): rating = 4
# Trailhead 190 at position (40, 14): rating = 6
# Trailhead 191 at position (40, 15): rating = 12
# Trailhead 192 at position (40, 25): rating = 4
# Trailhead 193 at position (40, 30): rating = 8
# Trailhead 194 at position (40, 32): rating = 4
# Trailhead 195 at position (41, 3): rating = 4
# Trailhead 196 at position (41, 6): rating = 1
# Trailhead 197 at position (41, 26): rating = 2
# Trailhead 198 at position (41, 30): rating = 6
# Trailhead 199 at position (41, 32): rating = 2
# Trailhead 200 at position (41, 38): rating = 1
# Trailhead 201 at position (42, 0): rating = 4
# Trailhead 202 at position (42, 6): rating = 3
# Trailhead 203 at position (42, 38): rating = 2
# Trailhead 204 at position (43, 20): rating = 18
# Trailhead 205 at position (43, 29): rating = 1
# Trailhead 206 at position (43, 30): rating = 4
# Trailhead 207 at position (44, 6): rating = 3
# Trailhead 208 at position (44, 15): rating = 6
# Trailhead 209 at position (44, 17): rating = 12
# Trailhead 210 at position (44, 21): rating = 25
# Trailhead 211 at position (44, 23): rating = 7
# Trailhead 212 at position (44, 30): rating = 1
# Trailhead 213 at position (44, 34): rating = 2
# Trailhead 214 at position (44, 43): rating = 2
#
# Sum of trailhead ratings: 1116
